# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# #LOADING BOSTON HOUSE DATA

# %%
from sklearn.datasets import fetch_california_housing

# %%
Housing = fetch_california_housing()

# %%
Housing.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'feature_names', 'DESCR'])

# %%
print(Housing.DESCR)
# Out:
# .. _california_housing_dataset:
#
# California Housing dataset
# --------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 20640
#
#     :Number of Attributes: 8 numeric, predictive attributes and the target
#
#     :Attribute Information:
#         - MedInc        median income in block group
#         - HouseAge      median house age in block group
#         - AveRooms      average number of rooms per household
#         - AveBedrms     average number of bedrooms per household
#         - Population    block group population
#         - AveOccup      average number of household members
#         - Latitude      block group latitude
#         - Longitude     block group longitude
#
#     :Missing Attribute Values: None
#
# This dataset was obtained from the StatLib repository.
# https://www.dcc.fc.up.pt/~ltorgo/Regression/cal_housing.html
#
# The target variable is the median house value for California districts,
# ...

# %%
from sklearn.datasets import fetch_openml

boston = fetch_openml(name="boston", as_frame=True)
boston_df = boston.frame
# Out:
# e:\MLProjects\bostonhousepricing\venv\lib\site-packages\sklearn\datasets\_openml.py:421: UserWarning: Multiple active versions of the dataset matching the name boston exist. Versions may be fundamentally different, returning version 1.
#   " {version}.".format(name=name, version=res[0]["version"])

# %%
boston_df.keys()
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT', 'MEDV'],
#       dtype='object')

# %%
boston_df.head()
# Out:
#       CRIM    ZN  INDUS CHAS    NOX     RM   AGE     DIS RAD    TAX  PTRATIO  \
# 0  0.00632  18.0   2.31    0  0.538  6.575  65.2  4.0900   1  296.0     15.3
# 1  0.02731   0.0   7.07    0  0.469  6.421  78.9  4.9671   2  242.0     17.8
# 2  0.02729   0.0   7.07    0  0.469  7.185  61.1  4.9671   2  242.0     17.8
# 3  0.03237   0.0   2.18    0  0.458  6.998  45.8  6.0622   3  222.0     18.7
# 4  0.06905   0.0   2.18    0  0.458  7.147  54.2  6.0622   3  222.0     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
boston.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'categories', 'feature_names', 'target_names', 'DESCR', 'details', 'url'])

# %%
print(boston.DESCR)
# Out:
# **Author**:
# **Source**: Unknown - Date unknown
# **Please cite**:
#
# The Boston house-price data of Harrison, D. and Rubinfeld, D.L. 'Hedonic
# prices and the demand for clean air', J. Environ. Economics & Management,
# vol.5, 81-102, 1978.   Used in Belsley, Kuh & Welsch, 'Regression diagnostics
# ...', Wiley, 1980.   N.B. Various transformations are used in the table on
# pages 244-261 of the latter.
# Variables in order:
# CRIM     per capita crime rate by town
# ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
# INDUS    proportion of non-retail business acres per town
# CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
# NOX      nitric oxides concentration (parts per 10 million)
# RM       average number of rooms per dwelling
# AGE      proportion of owner-occupied units built prior to 1940
# DIS      weighted distances to five Boston employment centres
# RAD      index of accessibility to radial highways
# ...

# %%
print(boston.target)
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
#        ...
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
# Name: MEDV, Length: 506, dtype: float64

# %%
boston_df.shape
# Out:
# (506, 14)

# %%
boston_df.describe()
# Out:
#              CRIM          ZN       INDUS         NOX          RM         AGE  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.554695    6.284634   68.574901
# std      8.601545   23.322453    6.860353    0.115878    0.702617   28.148861
# min      0.006320    0.000000    0.460000    0.385000    3.561000    2.900000
# 25%      0.082045    0.000000    5.190000    0.449000    5.885500   45.025000
# 50%      0.256510    0.000000    9.690000    0.538000    6.208500   77.500000
# 75%      3.677083   12.500000   18.100000    0.624000    6.623500   94.075000
# max     88.976200  100.000000   27.740000    0.871000    8.780000  100.000000
#
#               DIS         TAX     PTRATIO           B       LSTAT        MEDV
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.795043  408.237154   18.455534  356.674032   12.653063   22.532806
# ...

# %%
boston_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    category
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    category
#  9   TAX      506 non-null    float64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: category(2), float64(12)
# memory usage: 49.0 KB

# %%
boston_df.head()
# Out:
#       CRIM    ZN  INDUS CHAS    NOX     RM   AGE     DIS RAD    TAX  PTRATIO  \
# 0  0.00632  18.0   2.31    0  0.538  6.575  65.2  4.0900   1  296.0     15.3
# 1  0.02731   0.0   7.07    0  0.469  6.421  78.9  4.9671   2  242.0     17.8
# 2  0.02729   0.0   7.07    0  0.469  7.185  61.1  4.9671   2  242.0     17.8
# 3  0.03237   0.0   2.18    0  0.458  6.998  45.8  6.0622   3  222.0     18.7
# 4  0.06905   0.0   2.18    0  0.458  7.147  54.2  6.0622   3  222.0     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
# CHecking the missing VALUES

boston_df.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %%
boston_df["RAD"] = boston_df["RAD"].astype(float)
boston_df["CHAS"] = boston_df["CHAS"].astype(float)

# %%
boston_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    float64
#  9   TAX      506 non-null    float64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(14)
# memory usage: 55.5 KB

# %%
#### Exploratory Data Analysis

## Correlation (Super Important)

boston_df.corr()
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# ZN      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# INDUS    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# CHAS    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# NOX      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# RM      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# AGE      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# DIS     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# RAD      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# TAX      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# PTRATIO  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# ...

# %%
import seaborn as sns

plt.scatter(boston_df['CRIM'], boston_df['MEDV'])
#plt.xlabel("Crime")
#plt.ylabel("Price")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20424\2776271256.py in <module>
# ----> 1 import seaborn as sns
#       2
#       3 plt.scatter(boston_df['CRIM'], boston_df['MEDV'])
#       4 #plt.xlabel("Crime")
#       5 #plt.ylabel("Price")
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
sns.heatmap(boston_df.corr(), annot=True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20424\619450037.py in <module>
# ----> 1 sns.heatmap(boston_df.corr(), annot=True)
#       2 plt.show()
#
# NameError: name 'sns' is not defined

# %%
### we will drop RAD OR TAX because of multicollinearity

boston_df = boston_df.drop("RAD" , axis=1)

# %%
boston_df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS    TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  296.0     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  242.0     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  242.0     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  222.0     18.7
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  222.0     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
sns.heatmap(boston_df.corr(), annot=True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20424\619450037.py in <module>
# ----> 1 sns.heatmap(boston_df.corr(), annot=True)
#       2 plt.show()
#
# NameError: name 'sns' is not defined

# %%
plt.scatter(boston_df['LSTAT'], boston_df['MEDV'])

# %%
sns.regplot(x='LSTAT', y='MEDV' , data=boston_df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20424\3082267996.py in <module>
# ----> 1 sns.regplot(x='LSTAT', y='MEDV' , data=boston_df)
#
# NameError: name 'sns' is not defined

# %%
### Dependent & Independent DATA

X= boston_df.iloc[:, : -1]
y= boston_df.iloc[:,-1]


X.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS    TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  296.0     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  242.0     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  242.0     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  222.0     18.7
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  222.0     18.7
#
#         B  LSTAT
# 0  396.90   4.98
# 1  396.90   9.14
# 2  392.83   4.03
# 3  394.63   2.94
# 4  396.90   5.33

# %%
### TRAIN TEST SPLIT

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test= train_test_split(X,y, test_size=0.3 , random_state=42)

# %%
X_train
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS    TAX  PTRATIO  \
# 5     0.02985   0.0   2.18   0.0  0.458  6.430  58.7  6.0622  222.0     18.7
# 116   0.13158   0.0  10.01   0.0  0.547  6.176  72.5  2.7301  432.0     17.8
# 45    0.17142   0.0   6.91   0.0  0.448  5.682  33.8  5.1004  233.0     17.9
# 16    1.05393   0.0   8.14   0.0  0.538  5.935  29.3  4.4986  307.0     21.0
# 468  15.57570   0.0  18.10   0.0  0.580  5.926  71.0  2.9084  666.0     20.2
# ..        ...   ...    ...   ...    ...    ...   ...     ...    ...      ...
# 106   0.17120   0.0   8.56   0.0  0.520  5.836  91.9  2.2110  384.0     20.9
# 270   0.29916  20.0   6.96   0.0  0.464  5.856  42.1  4.4290  223.0     18.6
# 348   0.01501  80.0   2.01   0.0  0.435  6.635  29.7  8.3440  280.0     17.0
# 435  11.16040   0.0  18.10   0.0  0.740  6.629  94.6  2.1247  666.0     20.2
# 102   0.22876   0.0   8.56   0.0  0.520  6.405  85.4  2.7147  384.0     20.9
#
#           B  LSTAT
# 5    394.12   5.21
# ...

# %%
X_test
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS    TAX  PTRATIO  \
# 173  0.09178   0.0   4.05   0.0  0.510  6.416   84.1  2.6463  296.0     16.6
# 274  0.05644  40.0   6.41   1.0  0.447  6.758   32.9  4.0776  254.0     17.6
# 491  0.10574   0.0  27.74   0.0  0.609  5.983   98.8  1.8681  711.0     20.1
# 72   0.09164   0.0  10.81   0.0  0.413  6.065    7.8  5.2873  305.0     19.2
# 452  5.09017   0.0  18.10   0.0  0.713  6.297   91.8  2.3682  666.0     20.2
# ..       ...   ...    ...   ...    ...    ...    ...     ...    ...      ...
# 441  9.72418   0.0  18.10   0.0  0.740  6.406   97.2  2.0651  666.0     20.2
# 23   0.98843   0.0   8.14   0.0  0.538  5.813  100.0  4.0952  307.0     21.0
# 225  0.52693   0.0   6.20   0.0  0.504  8.725   83.0  2.8944  307.0     17.4
# 433  5.58107   0.0  18.10   0.0  0.713  6.436   87.9  2.3158  666.0     20.2
# 447  9.92485   0.0  18.10   0.0  0.740  6.251   96.6  2.1980  666.0     20.2
#
#           B  LSTAT
# 173  395.50   9.04
# ...

# %%
y_train
# Out:
# 5      28.7
# 116    21.2
# 45     19.3
# 16     23.1
# 468    19.1
#        ...
# 106    19.5
# 270    21.1
# 348    24.5
# 435    13.4
# 102    18.6
# Name: MEDV, Length: 354, dtype: float64

# %%
#Standarized

from sklearn.preprocessing import StandardScaler
Scaler=StandardScaler()

# %%
X_train = Scaler.fit_transform(X_train)

# %%
X_test = Scaler.transform(X_test)

# %%
import pickle
pickle.dump(Scaler, open('scaling.pkl' , 'wb'))

# %%
X_train
# Out:
# array([[-0.41425879, -0.50512499, -1.29214218, ...,  0.18727079,
#          0.39651419, -1.01531611],
#        [-0.40200818, -0.50512499, -0.16208345, ..., -0.21208981,
#          0.3870674 , -0.05366252],
#        [-0.39721053, -0.50512499, -0.60948856, ..., -0.16771641,
#          0.42854113, -0.31132373],
#        ...,
#        [-0.41604586,  3.03838247, -1.3166773 , ..., -0.56707702,
#          0.35987906, -0.90549329],
#        [ 0.92611293, -0.50512499,  1.00549958, ...,  0.8528718 ,
#         -2.87841346,  1.52750437],
#        [-0.39030549, -0.50512499, -0.37135358, ...,  1.16348561,
#         -3.32828832, -0.25218837]])

# %%
X_test
# Out:
# array([[-0.406801  , -0.50512499, -1.02225586, ..., -0.74457062,
#          0.41241246, -0.47605794],
#        [-0.41105674,  1.26662874, -0.68165068, ..., -0.30083661,
#          0.42854113, -1.25185755],
#        [-0.4051199 , -0.50512499,  2.39678516, ...,  0.8084984 ,
#          0.35031705,  0.79535229],
#        ...,
#        [-0.35439903, -0.50512499, -0.71195877, ..., -0.38958342,
#          0.25688594, -1.09697922],
#        [ 0.25423453, -0.50512499,  1.00549958, ...,  0.8528718 ,
#         -2.98970133,  0.53487511],
#        [ 0.77732457, -0.50512499,  1.00549958, ...,  0.8528718 ,
#          0.33199949,  0.56585078]])

# %% [markdown]
# #Model Training

# %%
from sklearn.linear_model import LinearRegression

# %%
Regression = LinearRegression()

# %%
Regression.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
## print the coefficients and intercepts

print(Regression.coef_)
# Out:
# [-0.82404407  0.61106514 -0.06392888  0.92524917 -1.55161796  3.06899161
#  -0.40677524 -2.87591624  0.33725404 -1.85690371  0.95587678 -3.82749521]

# %%
print(Regression.intercept_)
# Out:
# 23.01581920903955

# %%
## prediction with test data
Reg_predict = Regression.predict(X_test)
Reg_predict
# Out:
# array([28.52699545, 36.3284252 , 19.0094647 , 25.52345322, 18.18974051,
#        23.72470191, 17.50822805, 15.31893832, 21.92135453, 21.28207654,
#        24.34410643, 18.24750012, -6.22577985, 22.4724788 , 19.01832144,
#        25.5112776 , 18.72368674,  4.9959998 , 39.82568843, 16.99989936,
#        27.017543  , 29.55434104, 11.41315789, 24.77313119, 17.43414674,
#        14.93068999, 23.73706055, 14.44227631, 22.40454908, 20.00559078,
#        21.88952818, 25.17691071, 25.17850193, 17.63781952, 15.66801897,
#        18.20376424, 31.10415429, 19.66687403, 24.12334785, 25.06599705,
#        14.57682083, 30.47001245, 41.38639371, 18.1894102 , 27.5277813 ,
#        16.39223205, 14.22537812, 26.31987169, 19.34917245, 30.94279397,
#        20.98945936, 33.10322797, 16.11396338, 27.18867589, 38.8346933 ,
#        22.15634453, 18.29475937, 32.23615188, 24.90310843, 12.55720373,
#        21.97431125, 29.77111217, 31.11097089, 16.88105525, 22.44696392,
# ...

# %%
## Plot a scatter plot for the prediction
plt.scatter(y_test, Reg_predict)

# %%
## Residuals

Residuals = y_test - Reg_predict
Residuals
# Out:
# 173    -4.926995
# 274    -3.928425
# 491    -5.409465
# 72     -2.723453
# 452    -2.089741
#          ...
# 441     0.135421
# 23      0.701287
# 225    10.318215
# 433    -1.991895
# 447    -5.199144
# Name: MEDV, Length: 152, dtype: float64

# %%
sns.displot(Residuals, kind="kde")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20424\2165656757.py in <module>
# ----> 1 sns.displot(Residuals, kind="kde")
#
# NameError: name 'sns' is not defined

# %%
## Scatter Plot

plt.scatter(Reg_predict , Residuals)

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

print(mean_squared_error(y_test, Reg_predict))
print(mean_absolute_error(y_test, Reg_predict))
print(np.sqrt(mean_squared_error(y_test, Reg_predict)))
# Out:
# 23.225651753463115
# 3.2856443975416045
# 4.81929992358466

# %%
## R Square
from sklearn.metrics import r2_score
score = r2_score(y_test, Reg_predict)
score
# Out:
# 0.6883010754490929

# %% [markdown]
# # NEW DATA PREDICTION

# %%
boston.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'categories', 'feature_names', 'target_names', 'DESCR', 'details', 'url'])

# %%
New_boston=boston.data.drop("RAD" , axis=1)
New_data = New_boston.values

New_data[0].reshape(1, -1)
#boston_New = boston.data.values
#boston_New[0].reshape(1, -1)
# Out:
# array([[0.00632, 18.0, 2.31, '0', 0.538, 6.575, 65.2, 4.09, 296.0, 15.3,
#         396.9, 4.98]], dtype=object)

# %%
Scaler.transform(New_data[0].reshape(1, -1))
# Out:
# e:\MLProjects\bostonhousepricing\venv\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   "X does not have valid feature names, but"
# array([[-0.41709233,  0.29216419, -1.27338003, -0.28154625, -0.16513629,
#          0.34715902, -0.13030059,  0.15267164, -0.66777595, -1.32142483,
#          0.42854113, -1.04769976]])

# %%
New_data_predict = Regression.predict(Scaler.transform(New_data[0].reshape(1, -1)))

New_data_predict
# Out:
# e:\MLProjects\bostonhousepricing\venv\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   "X does not have valid feature names, but"
# array([30.94279397])

# %%
real = boston.target[0]

# %%
Residual_New = real - New_data_predict

Residual_New
# Out:
# array([-6.94279397])

# %% [markdown]
# # PICKLING THE MODEL FILE FOR DEPLOYMENT

# %%
import pickle

# %%
pickle.dump(Regression, open('regmodel.pkl', 'wb'))

# %%
pickled_model = pickle.load(open('regmodel.pkl' , 'rb'))

# %%
# Prediction with pickle File
pickled_model.predict(Scaler.transform(New_data[0].reshape(1, -1)))
# Out:
# e:\MLProjects\bostonhousepricing\venv\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   "X does not have valid feature names, but"
# array([30.94279397])
